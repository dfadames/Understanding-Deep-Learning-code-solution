# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-4bwqq71c
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-4bwqq71c
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (2.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post9-py3-none-any.whl size=14496 sha256=2320c95e2bdb6c02b7edd0c4712930d21fc574520a3267a2a501d1da8ec204a1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-105cpin1/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post9

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# at least 100 hidden units
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# at 50 hidden units
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
# at 200 hidden units

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302476, train error 89.72,  test loss 2.302680, test error 90.30
# Epoch   100, train loss 2.302361, train error 89.65,  test loss 2.303035, test error 89.88
# Epoch   200, train loss 2.302355, train error 89.65,  test loss 2.302902, test error 89.88
# Epoch   300, train loss 2.302359, train error 89.65,  test loss 2.302978, test error 89.88
# Epoch   400, train loss 2.302362, train error 89.65,  test loss 2.302845, test error 89.88
# Epoch   500, train loss 2.302360, train error 89.65,  test loss 2.303008, test error 89.88
# Epoch   600, train loss 2.302358, train error 89.65,  test loss 2.302937, test error 89.88
# Epoch   700, train loss 2.302359, train error 89.65,  test loss 2.302846, test error 89.88
# Epoch   800, train loss 2.302357, train error 89.65,  test loss 2.302963, test error 89.88
# Epoch   900, train loss 2.302357, train error 89.65,  test loss 2.303031, test error 89.88
# Training model with   4 hidden variables
# Epoch     0, train loss 2.302510, train error 88.72,  test loss 2.300332, test error 89.00
# Epoch   100, train loss 1.840272, train error 69.55,  test loss 1.695660, test error 68.12
# Epoch   200, train loss 1.832412, train error 69.40,  test loss 1.689971, test error 67.43
# Epoch   300, train loss 1.824617, train error 69.15,  test loss 1.700837, test error 67.43
# Epoch   400, train loss 1.816641, train error 69.12,  test loss 1.693881, test error 67.70
# Epoch   500, train loss 1.813024, train error 68.35,  test loss 1.701432, test error 67.75
# Epoch   600, train loss 1.810359, train error 68.22,  test loss 1.709588, test error 67.80
# Epoch   700, train loss 1.812968, train error 68.20,  test loss 1.721038, test error 68.25
# Epoch   800, train loss 1.809138, train error 68.07,  test loss 1.710589, test error 67.97
# Epoch   900, train loss 1.809877, train error 68.05,  test loss 1.715606, test error 67.35
# Training model with   6 hidden variables
# Epoch     0, train loss 2.232316, train error 83.05,  test loss 2.222518, test error 82.38
# Epoch   100, train loss 1.670546, train error 59.75,  test loss 1.487576, test error 57.10
# Epoch   200, train loss 1.651679, train error 59.15,  test loss 1.487711, test error 57.88
# Epoch   300, train loss 1.632689, train error 58.88,  test loss 1.485134, test error 56.85
# Epoch   400, train loss 1.624780, train error 58.90,  test loss 1.481316, test error 56.85
# Epoch   500, train loss 1.616161, train error 58.15,  test loss 1.494510, test error 56.90
# Epoch   600, train loss 1.612496, train error 58.55,  test loss 1.491134, test error 56.65
# Epoch   700, train loss 1.609318, train error 58.17,  test loss 1.502993, test error 57.15
# Epoch   800, train loss 1.604683, train error 57.42,  test loss 1.506311, test error 57.55
# Epoch   900, train loss 1.594311, train error 57.50,  test loss 1.495091, test error 57.10
# Training model with   8 hidden variables
# Epoch     0, train loss 2.260187, train error 83.82,  test loss 2.249117, test error 82.95
# Epoch   100, train loss 1.515622, train error 52.53,  test loss 1.335808, test error 49.17
# Epoch   200, train loss 1.481111, train error 50.78,  test loss 1.332592, test error 50.65
# Epoch   300, train loss 1.465926, train error 50.53,  test loss 1.319619, test error 49.88
# Epoch   400, train loss 1.458894, train error 50.45,  test loss 1.330420, test error 50.35
# Epoch   500, train loss 1.455036, train error 50.40,  test loss 1.337183, test error 50.47
# Epoch   600, train loss 1.449069, train error 50.10,  test loss 1.336448, test error 50.28
# Epoch   700, train loss 1.450479, train error 50.05,  test loss 1.340403, test error 50.38
# Epoch   800, train loss 1.450775, train error 50.83,  test loss 1.335627, test error 49.60
# Epoch   900, train loss 1.440841, train error 49.78,  test loss 1.336109, test error 49.80
# Training model with  10 hidden variables
# Epoch     0, train loss 2.244188, train error 83.60,  test loss 2.224358, test error 82.78
# Epoch   100, train loss 1.486753, train error 51.90,  test loss 1.278305, test error 47.60
# Epoch   200, train loss 1.426462, train error 48.20,  test loss 1.220869, test error 45.70
# Epoch   300, train loss 1.408317, train error 47.75,  test loss 1.218708, test error 45.15
# Epoch   400, train loss 1.390185, train error 47.30,  test loss 1.229420, test error 46.10
# Epoch   500, train loss 1.385068, train error 47.90,  test loss 1.239817, test error 46.33
# Epoch   600, train loss 1.384054, train error 47.95,  test loss 1.230373, test error 45.90
# Epoch   700, train loss 1.382276, train error 47.78,  test loss 1.235623, test error 46.10
# Epoch   800, train loss 1.371717, train error 47.30,  test loss 1.236885, test error 46.20
# Epoch   900, train loss 1.368597, train error 47.53,  test loss 1.258044, test error 46.97
# Training model with  14 hidden variables
# Epoch     0, train loss 2.227054, train error 83.03,  test loss 2.209754, test error 81.93
# Epoch   100, train loss 1.430013, train error 48.88,  test loss 1.324854, test error 49.95
# Epoch   200, train loss 1.341619, train error 45.65,  test loss 1.293487, test error 47.45
# Epoch   300, train loss 1.302219, train error 43.97,  test loss 1.307402, test error 47.67
# Epoch   400, train loss 1.281270, train error 42.88,  test loss 1.316144, test error 49.15
# Epoch   500, train loss 1.259256, train error 42.28,  test loss 1.344349, test error 48.50
# Epoch   600, train loss 1.257117, train error 42.28,  test loss 1.367649, test error 49.08
# Epoch   700, train loss 1.242600, train error 41.80,  test loss 1.380015, test error 49.28
# Epoch   800, train loss 1.242296, train error 42.00,  test loss 1.390065, test error 50.10
# Epoch   900, train loss 1.238180, train error 41.88,  test loss 1.402523, test error 49.58
# Training model with  18 hidden variables
# Epoch     0, train loss 2.153871, train error 80.68,  test loss 2.094573, test error 78.15
# Epoch   100, train loss 1.338157, train error 44.53,  test loss 1.267172, test error 47.55
# Epoch   200, train loss 1.258586, train error 41.90,  test loss 1.299831, test error 48.12
# Epoch   300, train loss 1.209760, train error 40.20,  test loss 1.324676, test error 48.17
# Epoch   400, train loss 1.181189, train error 39.28,  test loss 1.368729, test error 48.97
# Epoch   500, train loss 1.152095, train error 39.42,  test loss 1.387915, test error 49.30
# Epoch   600, train loss 1.147953, train error 39.03,  test loss 1.453846, test error 49.85
# Epoch   700, train loss 1.132112, train error 39.08,  test loss 1.504195, test error 51.10
# Epoch   800, train loss 1.132102, train error 38.80,  test loss 1.528818, test error 50.90
# Epoch   900, train loss 1.114303, train error 38.15,  test loss 1.542714, test error 50.42
# Training model with  22 hidden variables
# Epoch     0, train loss 2.170554, train error 80.05,  test loss 2.153248, test error 80.03
# Epoch   100, train loss 1.248198, train error 42.05,  test loss 1.277468, test error 47.00
# Epoch   200, train loss 1.145624, train error 39.22,  test loss 1.341159, test error 47.92
# Epoch   300, train loss 1.087870, train error 36.55,  test loss 1.407647, test error 49.75
# Epoch   400, train loss 1.066085, train error 36.15,  test loss 1.461668, test error 49.90
# Epoch   500, train loss 1.036793, train error 35.30,  test loss 1.511366, test error 50.75
# Epoch   600, train loss 1.010026, train error 34.53,  test loss 1.558523, test error 50.75
# Epoch   700, train loss 1.009292, train error 35.00,  test loss 1.656538, test error 52.45
# Epoch   800, train loss 0.998706, train error 35.47,  test loss 1.672849, test error 51.45
# Epoch   900, train loss 0.980128, train error 34.55,  test loss 1.694926, test error 51.92
# Training model with  26 hidden variables
# Epoch     0, train loss 2.137640, train error 78.18,  test loss 2.093030, test error 76.85
# Epoch   100, train loss 1.171133, train error 39.20,  test loss 1.366335, test error 49.25
# Epoch   200, train loss 1.024159, train error 34.60,  test loss 1.494262, test error 50.17
# Epoch   300, train loss 0.965456, train error 32.90,  test loss 1.593105, test error 51.22
# Epoch   400, train loss 0.913178, train error 30.53,  test loss 1.698361, test error 52.15
# Epoch   500, train loss 0.900997, train error 31.05,  test loss 1.742525, test error 52.08
# Epoch   600, train loss 0.879538, train error 29.65,  test loss 1.811450, test error 53.00
# Epoch   700, train loss 0.868811, train error 29.43,  test loss 1.887229, test error 54.10
# Epoch   800, train loss 0.854439, train error 29.20,  test loss 1.917724, test error 53.85
# Epoch   900, train loss 0.855380, train error 29.55,  test loss 1.953952, test error 53.62
# Training model with  30 hidden variables
# Epoch     0, train loss 2.160166, train error 79.20,  test loss 2.112858, test error 78.72
# Epoch   100, train loss 1.073816, train error 34.28,  test loss 1.299192, test error 47.85
# Epoch   200, train loss 0.909169, train error 30.07,  test loss 1.504076, test error 49.88
# Epoch   300, train loss 0.812715, train error 26.40,  test loss 1.693423, test error 51.03
# Epoch   400, train loss 0.781084, train error 26.28,  test loss 1.879305, test error 51.88
# Epoch   500, train loss 0.745210, train error 25.28,  test loss 2.062736, test error 53.62
# Epoch   600, train loss 0.738090, train error 25.43,  test loss 2.187757, test error 53.58
# Epoch   700, train loss 0.680561, train error 23.05,  test loss 2.339265, test error 53.22
# Epoch   800, train loss 0.691838, train error 24.20,  test loss 2.414765, test error 53.17
# Epoch   900, train loss 0.661762, train error 23.00,  test loss 2.547244, test error 52.30
# Training model with  35 hidden variables
# Epoch     0, train loss 2.126264, train error 77.85,  test loss 2.096602, test error 77.93
# Epoch   100, train loss 0.965369, train error 32.05,  test loss 1.421435, test error 49.53
# Epoch   200, train loss 0.728727, train error 24.00,  test loss 1.798753, test error 51.75
# Epoch   300, train loss 0.629652, train error 20.80,  test loss 2.194391, test error 54.22
# Epoch   400, train loss 0.564220, train error 19.30,  test loss 2.583341, test error 55.58
# Epoch   500, train loss 0.506491, train error 17.95,  test loss 2.926782, test error 55.33
# Epoch   600, train loss 0.490787, train error 17.50,  test loss 3.263139, test error 55.55
# Epoch   700, train loss 0.440176, train error 15.40,  test loss 3.703147, test error 56.50
# Epoch   800, train loss 0.451129, train error 16.18,  test loss 4.008291, test error 56.72
# Epoch   900, train loss 0.388861, train error 13.50,  test loss 4.252507, test error 56.35
# Training model with  40 hidden variables
# Epoch     0, train loss 2.162757, train error 79.97,  test loss 2.148811, test error 80.10
# Epoch   100, train loss 0.934018, train error 30.75,  test loss 1.486251, test error 50.95
# Epoch   200, train loss 0.646383, train error 21.30,  test loss 2.018842, test error 51.92
# Epoch   300, train loss 0.493830, train error 16.93,  test loss 2.701479, test error 53.80
# Epoch   400, train loss 0.398259, train error 13.30,  test loss 3.491374, test error 55.30
# Epoch   500, train loss 0.340214, train error 12.15,  test loss 4.266925, test error 56.55
# Epoch   600, train loss 0.337941, train error 11.93,  test loss 5.143810, test error 57.55
# Epoch   700, train loss 0.259343, train error 8.90,  test loss 5.896855, test error 57.45
# Epoch   800, train loss 0.262475, train error 9.43,  test loss 6.567967, test error 57.58
# Epoch   900, train loss 0.262708, train error 9.68,  test loss 7.223083, test error 58.03
# Training model with  45 hidden variables
# Epoch     0, train loss 2.133861, train error 79.22,  test loss 2.110653, test error 78.50
# Epoch   100, train loss 0.817190, train error 26.43,  test loss 1.491873, test error 48.88
# Epoch   200, train loss 0.496835, train error 15.62,  test loss 2.309520, test error 52.90
# Epoch   300, train loss 0.290523, train error 8.53,  test loss 3.325746, test error 53.88
# Epoch   400, train loss 0.238711, train error 7.97,  test loss 4.619855, test error 55.12
# Epoch   500, train loss 0.169014, train error 5.30,  test loss 5.850699, test error 54.58
# Epoch   600, train loss 0.037542, train error 0.30,  test loss 7.132166, test error 55.33
# Epoch   700, train loss 0.012552, train error 0.00,  test loss 8.218345, test error 56.10
# Epoch   800, train loss 0.008384, train error 0.00,  test loss 8.917262, test error 56.22
# Epoch   900, train loss 0.006333, train error 0.00,  test loss 9.441794, test error 56.25
# Training model with  50 hidden variables
# Epoch     0, train loss 2.061064, train error 76.88,  test loss 2.003495, test error 76.25
# Epoch   100, train loss 0.679069, train error 21.30,  test loss 1.586308, test error 51.12
# Epoch   200, train loss 0.295880, train error 7.65,  test loss 2.716374, test error 54.47
# Epoch   300, train loss 0.132606, train error 2.72,  test loss 4.346056, test error 55.08
# Epoch   400, train loss 0.024976, train error 0.00,  test loss 5.873488, test error 55.92
# Epoch   500, train loss 0.012263, train error 0.00,  test loss 6.781326, test error 55.65
# Epoch   600, train loss 0.007973, train error 0.00,  test loss 7.376319, test error 55.80
# Epoch   700, train loss 0.005863, train error 0.00,  test loss 7.836081, test error 55.83
# Epoch   800, train loss 0.004531, train error 0.00,  test loss 8.202631, test error 56.03
# Epoch   900, train loss 0.003615, train error 0.00,  test loss 8.507421, test error 56.08
# Training model with  55 hidden variables
# Epoch     0, train loss 2.100371, train error 77.30,  test loss 2.088721, test error 78.50
# Epoch   100, train loss 0.635845, train error 19.15,  test loss 1.625091, test error 49.70
# Epoch   200, train loss 0.220580, train error 5.20,  test loss 3.042062, test error 54.60
# Epoch   300, train loss 0.043200, train error 0.00,  test loss 4.681228, test error 54.65
# Epoch   400, train loss 0.015560, train error 0.00,  test loss 5.718074, test error 54.92
# Epoch   500, train loss 0.009021, train error 0.00,  test loss 6.349965, test error 55.05
# Epoch   600, train loss 0.006136, train error 0.00,  test loss 6.800131, test error 55.45
# Epoch   700, train loss 0.004576, train error 0.00,  test loss 7.150086, test error 55.25
# Epoch   800, train loss 0.003613, train error 0.00,  test loss 7.433796, test error 55.22
# Epoch   900, train loss 0.002950, train error 0.00,  test loss 7.678029, test error 55.30
# Training model with  60 hidden variables
# Epoch     0, train loss 2.061604, train error 75.75,  test loss 2.008388, test error 74.72
# Epoch   100, train loss 0.524240, train error 15.10,  test loss 1.698113, test error 50.30
# Epoch   200, train loss 0.123263, train error 1.88,  test loss 3.201120, test error 53.03
# Epoch   300, train loss 0.019825, train error 0.00,  test loss 4.473722, test error 52.97
# Epoch   400, train loss 0.009423, train error 0.00,  test loss 5.119685, test error 53.08
# Epoch   500, train loss 0.005946, train error 0.00,  test loss 5.541679, test error 53.25
# Epoch   600, train loss 0.004277, train error 0.00,  test loss 5.851456, test error 53.33
# Epoch   700, train loss 0.003284, train error 0.00,  test loss 6.095704, test error 53.25
# Epoch   800, train loss 0.002641, train error 0.00,  test loss 6.302585, test error 53.35
# Epoch   900, train loss 0.002197, train error 0.00,  test loss 6.475987, test error 53.22
# Training model with  70 hidden variables
# Epoch     0, train loss 2.027518, train error 75.38,  test loss 1.967159, test error 74.40
# Epoch   100, train loss 0.357427, train error 8.72,  test loss 1.905954, test error 50.97
# Epoch   200, train loss 0.032564, train error 0.00,  test loss 3.533070, test error 51.88
# Epoch   300, train loss 0.011005, train error 0.00,  test loss 4.294411, test error 52.60
# Epoch   400, train loss 0.006156, train error 0.00,  test loss 4.729370, test error 52.45
# Epoch   500, train loss 0.004121, train error 0.00,  test loss 5.036768, test error 52.62
# Epoch   600, train loss 0.003056, train error 0.00,  test loss 5.262808, test error 52.70
# Epoch   700, train loss 0.002396, train error 0.00,  test loss 5.446704, test error 52.72
# Epoch   800, train loss 0.001961, train error 0.00,  test loss 5.601787, test error 52.72
# Epoch   900, train loss 0.001647, train error 0.00,  test loss 5.738219, test error 52.75
# Training model with  80 hidden variables
# Epoch     0, train loss 2.019561, train error 75.45,  test loss 1.947518, test error 75.57
# Epoch   100, train loss 0.237494, train error 4.30,  test loss 1.996676, test error 49.75
# Epoch   200, train loss 0.020136, train error 0.00,  test loss 3.326588, test error 51.38
# Epoch   300, train loss 0.007905, train error 0.00,  test loss 3.879529, test error 51.20
# Epoch   400, train loss 0.004678, train error 0.00,  test loss 4.205644, test error 51.28
# Epoch   500, train loss 0.003208, train error 0.00,  test loss 4.433399, test error 50.92
# Epoch   600, train loss 0.002406, train error 0.00,  test loss 4.611611, test error 51.08
# Epoch   700, train loss 0.001916, train error 0.00,  test loss 4.758272, test error 51.22
# Epoch   800, train loss 0.001574, train error 0.00,  test loss 4.878386, test error 51.15
# Epoch   900, train loss 0.001330, train error 0.00,  test loss 4.984323, test error 51.15
# Training model with  90 hidden variables
# Epoch     0, train loss 2.019411, train error 72.80,  test loss 1.971064, test error 72.45
# Epoch   100, train loss 0.143248, train error 0.93,  test loss 2.153501, test error 51.62
# Epoch   200, train loss 0.015474, train error 0.00,  test loss 3.201146, test error 51.08
# Epoch   300, train loss 0.006687, train error 0.00,  test loss 3.656237, test error 51.42
# Epoch   400, train loss 0.004075, train error 0.00,  test loss 3.928332, test error 51.25
# Epoch   500, train loss 0.002862, train error 0.00,  test loss 4.121841, test error 51.03
# Epoch   600, train loss 0.002173, train error 0.00,  test loss 4.276070, test error 51.12
# Epoch   700, train loss 0.001736, train error 0.00,  test loss 4.400607, test error 51.17
# Epoch   800, train loss 0.001436, train error 0.00,  test loss 4.507709, test error 51.15
# Epoch   900, train loss 0.001218, train error 0.00,  test loss 4.598745, test error 51.15
# Training model with 100 hidden variables
# Epoch     0, train loss 2.007258, train error 74.10,  test loss 1.946114, test error 75.20
# Epoch   100, train loss 0.093794, train error 0.20,  test loss 2.180735, test error 50.85
# Epoch   200, train loss 0.012121, train error 0.00,  test loss 3.012061, test error 51.17
# Epoch   300, train loss 0.005604, train error 0.00,  test loss 3.359231, test error 51.05
# Epoch   400, train loss 0.003488, train error 0.00,  test loss 3.579110, test error 50.97
# Epoch   500, train loss 0.002478, train error 0.00,  test loss 3.737382, test error 51.17
# Epoch   600, train loss 0.001897, train error 0.00,  test loss 3.862784, test error 51.30
# Epoch   700, train loss 0.001523, train error 0.00,  test loss 3.966706, test error 51.42
# Epoch   800, train loss 0.001265, train error 0.00,  test loss 4.055276, test error 51.42
# Epoch   900, train loss 0.001077, train error 0.00,  test loss 4.131715, test error 51.33
# Training model with 120 hidden variables
# Epoch     0, train loss 1.955462, train error 72.43,  test loss 1.879482, test error 71.85
# Epoch   100, train loss 0.053642, train error 0.00,  test loss 2.280607, test error 50.10
# Epoch   200, train loss 0.009767, train error 0.00,  test loss 2.938145, test error 49.80
# Epoch   300, train loss 0.004790, train error 0.00,  test loss 3.237526, test error 49.85
# Epoch   400, train loss 0.003062, train error 0.00,  test loss 3.428141, test error 49.83
# Epoch   500, train loss 0.002203, train error 0.00,  test loss 3.569131, test error 49.78
# Epoch   600, train loss 0.001700, train error 0.00,  test loss 3.680381, test error 49.78
# Epoch   700, train loss 0.001373, train error 0.00,  test loss 3.772534, test error 49.88
# Epoch   800, train loss 0.001145, train error 0.00,  test loss 3.851544, test error 49.92
# Epoch   900, train loss 0.000978, train error 0.00,  test loss 3.920378, test error 49.92
# Training model with 140 hidden variables
# Epoch     0, train loss 1.968627, train error 73.05,  test loss 1.907713, test error 73.97
# Epoch   100, train loss 0.036741, train error 0.00,  test loss 2.076069, test error 48.60
# Epoch   200, train loss 0.008166, train error 0.00,  test loss 2.525676, test error 48.80
# Epoch   300, train loss 0.004189, train error 0.00,  test loss 2.746366, test error 48.75
# Epoch   400, train loss 0.002722, train error 0.00,  test loss 2.890342, test error 48.97
# Epoch   500, train loss 0.001979, train error 0.00,  test loss 2.997099, test error 48.97
# Epoch   600, train loss 0.001538, train error 0.00,  test loss 3.082705, test error 49.03
# Epoch   700, train loss 0.001249, train error 0.00,  test loss 3.153126, test error 49.10
# Epoch   800, train loss 0.001046, train error 0.00,  test loss 3.213287, test error 49.17
# Epoch   900, train loss 0.000895, train error 0.00,  test loss 3.265890, test error 49.12
# Training model with 160 hidden variables
# Epoch     0, train loss 1.932363, train error 70.62,  test loss 1.838145, test error 71.03
# Epoch   100, train loss 0.028905, train error 0.00,  test loss 2.116159, test error 48.97
# Epoch   200, train loss 0.007148, train error 0.00,  test loss 2.526671, test error 48.92
# Epoch   300, train loss 0.003756, train error 0.00,  test loss 2.730158, test error 49.08
# Epoch   400, train loss 0.002467, train error 0.00,  test loss 2.862896, test error 48.97
# Epoch   500, train loss 0.001807, train error 0.00,  test loss 2.960588, test error 49.05
# Epoch   600, train loss 0.001410, train error 0.00,  test loss 3.040831, test error 49.15
# Epoch   700, train loss 0.001149, train error 0.00,  test loss 3.105846, test error 49.22
# Epoch   800, train loss 0.000964, train error 0.00,  test loss 3.161428, test error 49.17
# Epoch   900, train loss 0.000828, train error 0.00,  test loss 3.210274, test error 49.17
# Training model with 180 hidden variables
# Epoch     0, train loss 1.908337, train error 70.12,  test loss 1.836334, test error 72.43
# Epoch   100, train loss 0.024997, train error 0.00,  test loss 2.024083, test error 47.80
# Epoch   200, train loss 0.006686, train error 0.00,  test loss 2.366184, test error 47.65
# Epoch   300, train loss 0.003564, train error 0.00,  test loss 2.539569, test error 47.55
# Epoch   400, train loss 0.002361, train error 0.00,  test loss 2.655742, test error 47.55
# Epoch   500, train loss 0.001736, train error 0.00,  test loss 2.744586, test error 47.58
# Epoch   600, train loss 0.001359, train error 0.00,  test loss 2.815798, test error 47.72
# Epoch   700, train loss 0.001109, train error 0.00,  test loss 2.874633, test error 47.72
# Epoch   800, train loss 0.000932, train error 0.00,  test loss 2.925704, test error 47.65
# Epoch   900, train loss 0.000801, train error 0.00,  test loss 2.969933, test error 47.65
# Training model with 200 hidden variables
# Epoch     0, train loss 1.924835, train error 70.50,  test loss 1.847503, test error 72.10
# Epoch   100, train loss 0.020875, train error 0.00,  test loss 1.953565, test error 46.62
# Epoch   200, train loss 0.006011, train error 0.00,  test loss 2.254969, test error 47.15
# Epoch   300, train loss 0.003271, train error 0.00,  test loss 2.410379, test error 47.08
# Epoch   400, train loss 0.002189, train error 0.00,  test loss 2.513230, test error 47.10
# Epoch   500, train loss 0.001619, train error 0.00,  test loss 2.592493, test error 47.05
# Epoch   600, train loss 0.001272, train error 0.00,  test loss 2.655244, test error 47.05
# Epoch   700, train loss 0.001042, train error 0.00,  test loss 2.708084, test error 46.95
# Epoch   800, train loss 0.000878, train error 0.00,  test loss 2.754185, test error 46.78
# Epoch   900, train loss 0.000756, train error 0.00,  test loss 2.793358, test error 46.80
# Training model with 250 hidden variables
# Epoch     0, train loss 1.920995, train error 69.53,  test loss 1.853789, test error 71.78
# Epoch   100, train loss 0.016974, train error 0.00,  test loss 1.922996, test error 47.53
# Epoch   200, train loss 0.005307, train error 0.00,  test loss 2.167366, test error 47.25
# Epoch   300, train loss 0.002955, train error 0.00,  test loss 2.303963, test error 47.25
# Epoch   400, train loss 0.001996, train error 0.00,  test loss 2.395384, test error 47.40
# Epoch   500, train loss 0.001485, train error 0.00,  test loss 2.465297, test error 47.40
# Epoch   600, train loss 0.001171, train error 0.00,  test loss 2.522402, test error 47.45
# Epoch   700, train loss 0.000961, train error 0.00,  test loss 2.569490, test error 47.53
# Epoch   800, train loss 0.000812, train error 0.00,  test loss 2.609944, test error 47.60
# Epoch   900, train loss 0.000700, train error 0.00,  test loss 2.645905, test error 47.55
# Training model with 300 hidden variables
# Epoch     0, train loss 1.877146, train error 67.43,  test loss 1.833255, test error 70.88
# Epoch   100, train loss 0.014413, train error 0.00,  test loss 1.859376, test error 47.25
# Epoch   200, train loss 0.004817, train error 0.00,  test loss 2.071499, test error 46.97
# Epoch   300, train loss 0.002734, train error 0.00,  test loss 2.186323, test error 47.12
# Epoch   400, train loss 0.001862, train error 0.00,  test loss 2.265937, test error 47.12
# Epoch   500, train loss 0.001394, train error 0.00,  test loss 2.326589, test error 47.00
# Epoch   600, train loss 0.001104, train error 0.00,  test loss 2.375629, test error 46.95
# Epoch   700, train loss 0.000909, train error 0.00,  test loss 2.416606, test error 47.15
# Epoch   800, train loss 0.000769, train error 0.00,  test loss 2.452340, test error 47.05
# Epoch   900, train loss 0.000665, train error 0.00,  test loss 2.483502, test error 47.10
# Training model with 400 hidden variables
# Epoch     0, train loss 1.822379, train error 66.68,  test loss 1.773177, test error 69.30
# Epoch   100, train loss 0.011532, train error 0.00,  test loss 1.770364, test error 46.25
# Epoch   200, train loss 0.004129, train error 0.00,  test loss 1.946949, test error 45.95
# Epoch   300, train loss 0.002395, train error 0.00,  test loss 2.045103, test error 46.08
# Epoch   400, train loss 0.001651, train error 0.00,  test loss 2.113747, test error 46.05
# Epoch   500, train loss 0.001245, train error 0.00,  test loss 2.166567, test error 45.97
# Epoch   600, train loss 0.000991, train error 0.00,  test loss 2.209335, test error 45.88
# Epoch   700, train loss 0.000820, train error 0.00,  test loss 2.245428, test error 45.92
# Epoch   800, train loss 0.000696, train error 0.00,  test loss 2.276689, test error 45.83
# Epoch   900, train loss 0.000603, train error 0.00,  test loss 2.304014, test error 45.83

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
